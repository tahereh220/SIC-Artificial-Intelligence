# %% [markdown]
# ## Coding Exercise #0208

# %% [markdown]
# ### 1. MultiIndex:

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1.1. Creating a DataFrame with MultiIndex:

# %%
my_header = ['A','B','C']

# %%
my_index_out = ['G1']*2 + ['G2']*2 + ['G3']*2
my_index_in = ['a', 'b']*3

# %%
print("my_header")
print(my_header)
print("\nmy_index_in")
print(my_index_in)
print("\nmy_index_out")
print(my_index_out)

# %%
#my_index_zipped = tuple(zip(my_index_out, my_index_in))
my_index_zipped = list(zip(my_index_out, my_index_in))
my_index_zipped
# Out:
# [('G1', 'a'), ('G1', 'b'), ('G2', 'a'), ('G2', 'b'), ('G3', 'a'), ('G3', 'b')]

# %%
my_multi_index = pd.MultiIndex.from_tuples(my_index_zipped)
print(my_multi_index)
df = pd.DataFrame(data=np.random.randn(6,3),index=my_multi_index,columns=my_header)
print(df)
# Out:
# MultiIndex([('G1', 'a'),
#             ('G1', 'b'),
#             ('G2', 'a'),
#             ('G2', 'b'),
#             ('G3', 'a'),
#             ('G3', 'b')],
#            )
#              A         B         C
# G1 a -0.140709 -0.455126  0.218006
#    b -1.638762  0.272584 -0.750193
# G2 a -1.317463  1.317442 -1.261255
#    b  1.314081  0.347042  1.232845
# G3 a -0.426153  1.508688  2.193528
#    b  0.777600  0.496484 -2.467703

# %%
df
# Out:
#              A         B         C
# G1 a -0.140709 -0.455126  0.218006
#    b -1.638762  0.272584 -0.750193
# G2 a -1.317463  1.317442 -1.261255
#    b  1.314081  0.347042  1.232845
# G3 a -0.426153  1.508688  2.193528
#    b  0.777600  0.496484 -2.467703

# %% [markdown]
# #### 1.2. Indexing and slicing DataFrames with MultiIndex:

# %%
df.loc['G1']
# Out:
#           A         B         C
# a -0.140709 -0.455126  0.218006
# b -1.638762  0.272584 -0.750193

# %%
# Indexing followed by another indexing.
df.loc['G1'].loc['a']
# Out:
# A   -0.140709
# B   -0.455126
# C    0.218006
# Name: a, dtype: float64

# %%
# Indexing followed by another indexing.
df.loc['G1'].loc['a','B']
# Out:
# -0.45512639222940526

# %% [markdown]
# ### 2. DataFrame summarization:

# %% [markdown]
# #### 2.1. Group by method:

# %%
# !wget --no-clobber https://raw.githubusercontent.com/stefannae/SIC-Artificial-Intelligence/main/SIC_AI_Coding_Exercises/SIC_AI_Chapter_03_Coding_Exercises/data_studentlist.csv
# Out:
# File ‘data_studentlist.csv’ already there; not retrieving.

# %%
df = pd.read_csv('data_studentlist.csv',header='infer')

# %%
print(df.shape)
df.head(3)
df
# Out:
# (17, 8)
#                 name gender  age  grade absence bloodtype  height  weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 16       Andrew King      M   21      1       N         A   169.2    62.2

# %%
dfr = pd.pivot_table(df, index=['gender','absence'], columns='bloodtype', values='height')
dfr
# Out:
# bloodtype           A      AB           B           O
# gender absence
# F      N        176.9  170.10  158.200000  164.433333
#        Y        168.0     NaN         NaN         NaN
# M      N        165.7  181.05  176.533333         NaN
#        Y          NaN     NaN  168.600000  166.200000

# %%
print(df.groupby(['gender', 'bloodtype']).mean())
print(df.groupby('gender').mean())
print(df.groupby(['gender', 'bloodtype'])['grade'].mean())
# Out:
#                     age  grade      height     weight
# gender bloodtype
# F      A          21.50   1.00  172.450000  52.250000
#        AB         22.00   2.00  170.100000  53.000000
#        B          22.00   2.00  158.200000  45.200000
#        O          22.00   2.00  164.433333  50.133333
# M      A          21.00   1.00  165.700000  58.750000
#        AB         22.50   2.50  181.050000  80.750000
#        B          23.25   3.25  174.550000  68.950000
#        O          23.50   3.50  166.200000  65.100000
#               age     grade      height     weight
# gender
# F       21.857143  1.714286  166.642857  50.442857
# M       22.700000  2.700000  172.410000  68.500000
# gender  bloodtype
# F       A            1.00
#         AB           2.00
#         B            2.00
#         O            2.00
# M       A            1.00
#         AB           2.50
#         B            3.25
#         O            3.50
# Name: grade, dtype: float64

# %%
df.groupby('gender')['height'].mean()
# Out:
# gender
# F    166.642857
# M    172.410000
# Name: height, dtype: float64

# %%
df.groupby('gender')[['height','weight']].mean()
# Out:
#             height     weight
# gender
# F       166.642857  50.442857
# M       172.410000  68.500000

# %%
df.groupby('gender')[['grade','age']].std()
# Out:
#            grade       age
# gender
# F       0.755929  1.069045
# M       1.159502  1.159502

# %%
df.groupby('gender')['height'].describe()
# Out:
#         count        mean       std    min      25%    50%    75%    max
# gender
# F         7.0  166.642857  8.487414  155.2  160.100  168.0  173.1  176.9
# M        10.0  172.410000  6.804647  162.2  167.475  172.1  177.9  182.1

# %%
sr = df.groupby(['gender','bloodtype'])['height'].mean()     # MultiIndexed result.
sr
# Out:
# gender  bloodtype
# F       A            172.450000
#         AB           170.100000
#         B            158.200000
#         O            164.433333
# M       A            165.700000
#         AB           181.050000
#         B            174.550000
#         O            166.200000
# Name: height, dtype: float64

# %%
sr.loc['F']
# Out:
# bloodtype
# A     172.450000
# AB    170.100000
# B     158.200000
# O     164.433333
# Name: height, dtype: float64

# %%
sr.loc['F'].loc['A']
# Out:
# 172.45

# %% [markdown]
# #### 2.2.  DataFrame methods:

# %%
df['height'].apply(lambda x: x/100)
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
df.sort_values(by='bloodtype')
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2

# %%
df.sort_values(by='bloodtype', ascending=False)
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 16       Andrew King      M   21      1       N         A   169.2    62.2

# %%
df.sort_values(by=['bloodtype','gender'])
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# 5   Jennifer Lorentz      F   21      2       N         O   162.0    52.0
# 6        Susan Clark      F   22      1       N         O   155.2    45.3
# 13  Rebecah Anderson      F   23      3       N         O   176.1    53.1
# 0      Jared Diamond      M   23      3       Y         O   165.3    68.2
# 10     Joshua Connor      M   24      4       Y         O   167.1    62.0

# %%
df['bloodtype'].unique()
# Out:
# array(['O', 'AB', 'B', 'A'], dtype=object)

# %%
df['bloodtype'].nunique()
# Out:
# 4

# %%
# Frequency table.
df['bloodtype'].value_counts()
# Out:
# O     5
# B     5
# A     4
# AB    3
# Name: bloodtype, dtype: int64

# %%
# Frequency table.
df['gender'].value_counts()
# Out:
# M    10
# F     7
# Name: gender, dtype: int64

# %% [markdown]
# #### 2.3. Pivoting:

# %%
my_dict = {"Size": ["L", "L", "M", "M", "M", "S", "S", "S", "S"],
           "Type": ["A", "A", "A", "B", "B", "A", "A", "B", "B"],
            "Location": ["L1", "L1", "L1", "L2", "L2", "L1", "L2", "L2", "L1"],
            "A": [1, 2, 2, 3, 3, 4, 5, 6, 7],
            "B": [2, 4, 5, 5, 6, 6, 8, 9, 9]}
df = pd.DataFrame(my_dict)
df
# Out:
#   Size Type Location  A  B
# 0    L    A       L1  1  2
# 1    L    A       L1  2  4
# 2    M    A       L1  2  5
# 3    M    B       L2  3  5
# 4    M    B       L2  3  6
# 5    S    A       L1  4  6
# 6    S    A       L2  5  8
# 7    S    B       L2  6  9
# 8    S    B       L1  7  9

# %%
# Index by 'Size' and 'Type'. Columns by 'Location'. Values provided by the 'B' column.
dfr = pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B')      
dfr
# Out:
# Location    L1   L2
# Size Type
# L    A     3.0  NaN
# M    A     5.0  NaN
#      B     NaN  5.5
# S    A     6.0  8.0
#      B     9.0  9.0

# %%
dfr.columns
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.index                                                                 # MultiIndex object!
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# The same as above, but fill the missing values with 0.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# The same as above with the aggregation function specified.
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.mean, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Index by ''Location'. Columns by 'Size' and 'Type'. Values provided by the 'B' column.
dfr = pd.pivot_table(df, index='Location', columns=['Size','Type'], values='B')
dfr
# Out:
# Size        L    M         S
# Type        A    A    B    A    B
# Location
# L1        3.0  5.0  NaN  6.0  9.0
# L2        NaN  NaN  5.5  8.0  9.0

# %%
dfr.index
# Out:
# Index(['L1', 'L2'], dtype='object', name='Location')

# %%
dfr.columns                                                           # Now, MultiIndex object for the columns.
# Out:
# MultiIndex([('L', 'A'),
#             ('M', 'A'),
#             ('M', 'B'),
#             ('S', 'A'),
#             ('S', 'B')],
#            names=['Size', 'Type'])

# %%
# The aggregation funciton is numpy.median().
pd.pivot_table(df, index=['Size','Type'], columns='Location', values='B', aggfunc = np.median, fill_value=0)
# Out:
# Location   L1   L2
# Size Type
# L    A      3  0.0
# M    A      5  0.0
#      B      0  5.5
# S    A      6  8.0
#      B      9  9.0

# %%
# Group averages of the columns 'A' abd 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc=np.mean)
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Now, with groupby() method.
# The result is the same. 
df.groupby(['Size','Type'])[['A','B']].mean()
# Out:
#              A    B
# Size Type
# L    A     1.5  3.0
# M    A     2.0  5.0
#      B     3.0  5.5
# S    A     4.5  7.0
#      B     6.5  9.0

# %%
# Aggregate differenly the columns 'A' and 'B'.
pd.pivot_table(df, index=['Size','Type'], values=['A','B'], aggfunc={'A':np.max,'B':np.min})
# Out:
#            A  B
# Size Type
# L    A     2  2
# M    A     2  5
#      B     3  5
# S    A     5  6
#      B     7  9
